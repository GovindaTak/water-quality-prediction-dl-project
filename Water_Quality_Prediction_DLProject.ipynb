# %% [markdown]
# # Project: Introduction to DL-Problem statement
#
# In this project, we analysis a water quality dataset from the Central Pollution Control Board (CPCB). we will use this dataset to predict water quality.
#
# Access to clean water is a fundamental necessity, yet water quality can vary significantly based on environmental, geographical, and human factors. The dataset includes water quality monitoring data from across India, with chemical and physical parameters measured at various locations over different years (2019, 2020, 2021, 2022).
#
# The dataset contains the following columns:
#
# Well_ID, State, District, Block, Village: Geographical identifiers of water sampling locations.
#
# Latitude, Longitude: Spatial coordinates for precise mapping.
#
# Year: The year in which the sample was recorded.
#
# Water Quality Indicators: pH, Electrical Conductivity (EC), Carbonates (CO3), Bicarbonates (HCO3), Chlorides (Cl), Sulfates (SO4), Nitrates (NO3), Total Hardness (TH), Calcium (Ca), Magnesium (Mg), Sodium (Na), Potassium (K), Fluoride (F), Total Dissolved Solids (TDS).
#
# # Target Variables:
# 1) Water Quality Index (WQI): A numerical representation of overall water quality derived from chemical and physical parameters.
#
# 2) Water Quality Classification: A categorical label indicating the quality of water (e.g., Good, Poor, Unsuitable for Drinking).
#
# In this project, our task is to build Deep Learning Neural Networks to predict the following:
# Water Quality Index (WQI)
# Water Quality Classification
#
# we can download the dataset from the attachment provided and build the models using that.

# %% [markdown]
# # Step 1:- import basic library for data preprocessing and data analysis and also import dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('WknaT6YxR02YeXYuMDPg_water_quality.csv')

# %%
#let's check basic information about our dataset
data.head()
# Out:
#             Well_ID             State    District      Block    Village  \
# 0  W232200071580001           Gujarat   Ahmedabad     Mandal      Dalod
# 1  W254029084355301  Himachal Pradesh       Solan  Nallagarh   JAGATPUR
# 2  W193530074180001       Maharashtra  Ahmednagar  SANGAMNER  Kokangaon
# 3  W231620072033001           Gujarat   Ahmedabad   Viramgam      Endla
# 4  W251908084361501  Himachal Pradesh       Solan  Nallagarh     BARUNA
#
#    Latitude  Longitude  Year    pH       EC  ...    NO3      TH     Ca     Mg  \
# 0       NaN        NaN  2020  8.20  16640.0  ...  26.00  1451.0  152.0  260.0
# 1   31.1594  76.678500  2019  8.44    299.0  ...   2.70    84.0   17.0   10.0
# 2   74.3000  19.591667  2022  7.90   1315.0  ...  18.20   465.0   80.2   64.4
# 3       NaN        NaN  2020  7.40    715.0  ...   0.23   280.0   56.0   34.0
# 4   31.1540  76.638400  2019  8.40    270.0  ...  10.00   116.0   10.0   18.0
#
#        Na     K     F    TDS         WQI  Water Quality Classification
# 0  3535.0  45.0  1.00  11149  4361.44080       Unsuitable for Drinking
# 1    39.0   2.4  0.20    262    85.80466                          Good
# 2    88.3   1.6  0.53    372   280.04130       Very Poor yet Drinkable
# 3    47.0  11.0  0.46    479   195.11649                          Poor
# 4    23.0   1.0  0.12    262    81.77860                          Good
#
# [5 rows x 24 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19029 entries, 0 to 19028
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Well_ID                       15244 non-null  object
#  1   State                         19029 non-null  object
#  2   District                      19029 non-null  object
#  3   Block                         17910 non-null  object
#  4   Village                       19028 non-null  object
#  5   Latitude                      18640 non-null  float64
#  6   Longitude                     18639 non-null  float64
#  7   Year                          19029 non-null  int64
#  8   pH                            19029 non-null  float64
#  9   EC                            19029 non-null  float64
#  10  CO3                           19029 non-null  float64
#  11  HCO3                          19029 non-null  float64
#  12  Cl                            19029 non-null  float64
#  13  SO4                           19029 non-null  float64
#  14  NO3                           19029 non-null  float64
#  15  TH                            19029 non-null  float64
#  16  Ca                            19029 non-null  float64
#  17  Mg                            19029 non-null  float64
#  18  Na                            19029 non-null  float64
#  19  K                             19029 non-null  float64
#  20  F                             19029 non-null  float64
#  21  TDS                           19029 non-null  int64
#  22  WQI                           19029 non-null  float64
#  23  Water Quality Classification  19029 non-null  object
# dtypes: float64(16), int64(2), object(6)
# memory usage: 3.5+ MB

# %%
data.describe().transpose()
# Out:
#              count         mean            std          min         25%  \
# Latitude   18640.0   150.904931   15292.040585     0.000000    19.98330
# Longitude  18639.0  4021.431802  540151.202121     0.000000    25.22500
# Year       19029.0  2020.286195       1.314794  2019.000000  2019.00000
# pH         19029.0     7.713495       0.491413     2.800000     7.45000
# EC         19029.0  1191.620744    1348.094278     2.290000   524.00000
# CO3        19029.0     3.326689      15.496995     0.000000     0.00000
# HCO3       19029.0   296.774490     180.861685     0.000000   177.00000
# Cl         19029.0   171.843482     349.922000     0.000000    32.00000
# SO4        19029.0    68.087940     148.853626     0.000000    13.00000
# NO3        19029.0    35.114294      55.488528     0.000000     4.46000
# TH         19029.0   327.843466     310.386082     3.000000   165.00000
# Ca         19029.0    65.114035      62.018322     0.000000    28.10000
# Mg         19029.0    40.505256      49.654295     0.000000    15.00000
# Na         19029.0   113.673866     200.551600     0.000000    28.00000
# K          19029.0    13.465496      38.839328     0.000000     1.70000
# F          19029.0     0.595598       1.818577    -0.160000     0.20600
# TDS        19029.0   723.774239     755.575601    15.000000   345.00000
# WQI        19029.0   305.291789     315.477116     9.043604   146.64242
#
#                    50%         75%           max
# Latitude     24.178415    75.71110  2.087833e+06
# Longitude    76.175000    79.53710  7.374400e+07
# Year       2020.000000  2022.00000  2.022000e+03
# pH            7.720000     8.00000  1.092000e+01
# EC          860.000000  1390.00000  2.652000e+04
# CO3           0.000000     0.00000  3.680000e+02
# HCO3        281.000000   390.40000  3.112000e+03
# Cl           78.000000   175.00000  9.217000e+03
# SO4          30.790000    69.00000  7.601000e+03
# NO3          18.000000    43.00000  1.534900e+03
# TH          260.000000   400.00000  8.606880e+03
# Ca           50.100000    80.00000  1.840000e+03
# Mg           29.000000    49.80000  1.483500e+03
# Na           60.400000   121.00000  5.489000e+03
# K             3.630000     9.51000  1.353000e+03
# F             0.430000     0.77000  1.680000e+02
# TDS         587.000000   913.00000  1.776800e+04
# WQI         232.078880   359.71824  6.850889e+03

# %% [markdown]
# # Step 2 :- Data cleaning :- handle the null values

# %%
# list of column who have null values :- 
data.isnull().sum()
# Out:
# Well_ID                         3785
# State                              0
# District                           0
# Block                           1119
# Village                            1
# Latitude                         389
# Longitude                        390
# Year                               0
# pH                                 0
# EC                                 0
# CO3                                0
# HCO3                               0
# Cl                                 0
# SO4                                0
# NO3                                0
# TH                                 0
# Ca                                 0
# Mg                                 0
# Na                                 0
# K                                  0
# F                                  0
# TDS                                0
# WQI                                0
# Water Quality Classification       0
# dtype: int64

# %%
# One thing we can observe then well_ID is not nessasary to predict our target ,so we drop it.
data.drop('Well_ID',inplace=True,axis=1)

# %%
# let's 1stly work on block :-
data['Block'].nunique()
# Out:
# 5055

# %% [markdown]
# Because of categorical column and have so much unique values and only 1 row containing null values ,so we 2 options :- a)replace null by 'NA' b)we can drop it ,it will never impact our model so much.

# %%
data.fillna({'Block':'NA'},inplace=True)
data.isnull().sum()
# Out:
# State                             0
# District                          0
# Block                             0
# Village                           1
# Latitude                        389
# Longitude                       390
# Year                              0
# pH                                0
# EC                                0
# CO3                               0
# HCO3                              0
# Cl                                0
# SO4                               0
# NO3                               0
# TH                                0
# Ca                                0
# Mg                                0
# Na                                0
# K                                 0
# F                                 0
# TDS                               0
# WQI                               0
# Water Quality Classification      0
# dtype: int64

# %%
# Let's work on village ;- 
data['Village'].nunique()
# Out:
# 11210

# %%
# We can take similar action as taken in block case.
data.fillna({'Village':'NA'},inplace=True)
data.isnull().sum()
# Out:
# State                             0
# District                          0
# Block                             0
# Village                           0
# Latitude                        389
# Longitude                       390
# Year                              0
# pH                                0
# EC                                0
# CO3                               0
# HCO3                              0
# Cl                                0
# SO4                               0
# NO3                               0
# TH                                0
# Ca                                0
# Mg                                0
# Na                                0
# K                                 0
# F                                 0
# TDS                               0
# WQI                               0
# Water Quality Classification      0
# dtype: int64

# %% [markdown]
# Let's handle longitude and latitude null value
# we can fill the these values by taking the median of those rows who have same state and distict values.
# # Note :-
# we will fill these values from training data set after spliting, because to avoid data leaking.

# %% [markdown]
# # Step 3 :- Data visuaization
# let's see the spreading of data and the co-relation between them and distribution of target variables and so on.

# %%
# Let's see distribution of our target variabes :-
sns.displot(data,x='WQI')
plt.xlim(0,3000)
# Out:
# (0.0, 3000.0)

# %% [markdown]
# so we can see , to predict WQI , is a regression problem .

# %%
sns.displot(data,x='Water Quality Classification')
plt.figure(figsize=(12,600))

# %%
data['Water Quality Classification'].unique()
# Out:
# array(['Unsuitable for Drinking', 'Good', 'Very Poor yet Drinkable',
#        'Poor', 'Excellent'], dtype=object)

# %%
data.groupby('Water Quality Classification')['Water Quality Classification'].count()
# Out:
# Water Quality Classification
# Excellent                   763
# Good                       1632
# Poor                       5317
# Unsuitable for Drinking    6608
# Very Poor yet Drinkable    4709
# Name: Water Quality Classification, dtype: int64

# %%
#Let's see the co-relation between the columns 
data.corr(numeric_only=True)['WQI']
# Out:
# Latitude    -0.004263
# Longitude   -0.003164
# Year        -0.023797
# pH           0.012890
# EC           0.981442
# CO3          0.096421
# HCO3         0.493898
# Cl           0.932176
# SO4          0.705896
# NO3          0.380014
# TH           0.822221
# Ca           0.624723
# Mg           0.776863
# Na           0.903628
# K            0.274142
# F            0.092698
# TDS          0.924358
# WQI          1.000000
# Name: WQI, dtype: float64

# %%
plt.figure(figsize=(15,22))
sns.heatmap(data.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Note :-
# We can observe that there is many columns are highly co-related , if we also all columns then our model will be overfitted , to avoid that we can drop the one of column between highly co-related columns pair.

# %% [markdown]
# # Step 4 :- applying feature engineering

# %%
#Let's list out highly co-related column pairs 
thresold =0.8
corr_matrix=data.corr(numeric_only=True)
highly_corr_pairs=[(col1,col2) for col1 in corr_matrix.columns for col2 in corr_matrix.columns if (col1 != col2) and abs(corr_matrix.loc[col1,col2] > thresold)]
print(highly_corr_pairs)
# Out:
# [('EC', 'Cl'), ('EC', 'TH'), ('EC', 'Na'), ('EC', 'TDS'), ('EC', 'WQI'), ('Cl', 'EC'), ('Cl', 'TH'), ('Cl', 'Na'), ('Cl', 'TDS'), ('Cl', 'WQI'), ('TH', 'EC'), ('TH', 'Cl'), ('TH', 'Ca'), ('TH', 'Mg'), ('TH', 'WQI'), ('Ca', 'TH'), ('Mg', 'TH'), ('Na', 'EC'), ('Na', 'Cl'), ('Na', 'WQI'), ('TDS', 'EC'), ('TDS', 'Cl'), ('TDS', 'WQI'), ('WQI', 'EC'), ('WQI', 'Cl'), ('WQI', 'TH'), ('WQI', 'Na'), ('WQI', 'TDS')]

# %%
col_to_drop=set()
for col1,col2 in highly_corr_pairs:
    if (col1 !='WQI') and (col2 !='WOI'):
        if corr_matrix.loc['WQI',col1] >= corr_matrix.loc['WQI',col2]:
            col_to_drop.add(col2)
        else :
            col_to_drop.add(col1)

filter_data=data.drop(columns=col_to_drop)

# %%
filter_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19029 entries, 0 to 19028
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   State                         19029 non-null  object
#  1   District                      19029 non-null  object
#  2   Block                         19029 non-null  object
#  3   Village                       19029 non-null  object
#  4   Latitude                      18640 non-null  float64
#  5   Longitude                     18639 non-null  float64
#  6   Year                          19029 non-null  int64
#  7   pH                            19029 non-null  float64
#  8   CO3                           19029 non-null  float64
#  9   HCO3                          19029 non-null  float64
#  10  SO4                           19029 non-null  float64
#  11  NO3                           19029 non-null  float64
#  12  K                             19029 non-null  float64
#  13  F                             19029 non-null  float64
#  14  WQI                           19029 non-null  float64
#  15  Water Quality Classification  19029 non-null  object
# dtypes: float64(10), int64(1), object(5)
# memory usage: 2.3+ MB

# %% [markdown]
# Now we have only 16 columns from 24.

# %% [markdown]
# # Step 5:- Data Preprocessing
# it's include to handle data format , spliting of data and preparing train and test set.

# %%
obj_col=data.select_dtypes(include='O').columns
print(obj_col)
# Out:
# Index(['State', 'District', 'Block', 'Village',
#        'Water Quality Classification'],
#       dtype='object')

# %%
# let's check their unique values :-
for col in obj_col:
    print(f'{col} : {data[col].nunique()}')
# Out:
# State : 14
# District : 600
# Block : 5056
# Village : 11211
# Water Quality Classification : 5

# %% [markdown]
# As we can see here top 4 column have so much unique value and we already have longitude and latitude values so don't neet these values also, so we can drop these columns but after fill null values of train test set.

# %% [markdown]
# For Water Quality Classification , it have natural ordered hierarical order of water quality so we can use OrdinalEncoder to handle it.

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
data['Water Quality Classification'].unique()
# Out:
# array(['Unsuitable for Drinking', 'Good', 'Very Poor yet Drinkable',
#        'Poor', 'Excellent'], dtype=object)

# %%
encoder=OrdinalEncoder(categories=[['Unsuitable for Drinking', 'Very Poor yet Drinkable', 'Poor', 'Good', 'Excellent']]) #must be in ordered way

# %%
filter_data['Water Quality Classification']=encoder.fit_transform(filter_data[['Water Quality Classification']])

# %%
filter_data['Water Quality Classification']
# Out:
# 0        0.0
# 1        3.0
# 2        1.0
# 3        2.0
# 4        3.0
#         ...
# 19024    0.0
# 19025    2.0
# 19026    0.0
# 19027    2.0
# 19028    1.0
# Name: Water Quality Classification, Length: 19029, dtype: float64

# %%
filter_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19029 entries, 0 to 19028
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   State                         19029 non-null  object
#  1   District                      19029 non-null  object
#  2   Block                         19029 non-null  object
#  3   Village                       19029 non-null  object
#  4   Latitude                      18640 non-null  float64
#  5   Longitude                     18639 non-null  float64
#  6   Year                          19029 non-null  int64
#  7   pH                            19029 non-null  float64
#  8   CO3                           19029 non-null  float64
#  9   HCO3                          19029 non-null  float64
#  10  SO4                           19029 non-null  float64
#  11  NO3                           19029 non-null  float64
#  12  K                             19029 non-null  float64
#  13  F                             19029 non-null  float64
#  14  WQI                           19029 non-null  float64
#  15  Water Quality Classification  19029 non-null  float64
# dtypes: float64(11), int64(1), object(4)
# memory usage: 2.3+ MB

# %%
#Let 's prepare X and Y data set.
X=filter_data.drop(['WQI','Water Quality Classification'],axis=1)
Y1=filter_data['WQI']
Y2=filter_data['Water Quality Classification']

# %%
#Let's split dataset 
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y1_train, Y1_test = train_test_split(X, Y1, test_size=0.2, random_state=42)
X_train, X_test, Y2_train, Y2_test = train_test_split(X, Y2, test_size=0.2, random_state=42)

# %% [markdown]
# __Let's handle null data in longitude and latitude columns.__
# we take median of these columns according to state distict and village information by train set and then fill it.

# %%
lat_median=X_train.groupby(by=['State','District','Block'])['Latitude'].median()
lat_median
# Out:
# State           District        Block
# Andhra Pradesh  ANANTAPUR       ANANTAPUR     77.504000
#                                 ATMAKUR       77.365556
#                                 Agali         77.023600
#                                 Amadagur      78.015653
#                                 Amarapuram    76.977800
#                                                 ...
# West Bengal     Uttar Dinajpur  Islampur      88.132400
#                                 Itahar        56.837050
#                                 Kaliaganj     88.250000
#                                 Karandighi    56.859850
#                                 Raiganj       25.707900
# Name: Latitude, Length: 5307, dtype: float64

# %%
X_train['Latitude']=X_train['Latitude'].fillna(X_train.groupby(['State','District','Block'])['Latitude'].transform('median'))
X_train['Latitude'].isnull().sum()
# Out:
# 163

# %%
X_train['Latitude']=X_train['Latitude'].fillna(X_train.groupby(['State','District'])['Latitude'].transform('median'))
X_train['Latitude'].isnull().sum()
# Out:
# 77

# %%
X_train['Latitude']=X_train['Latitude'].fillna(X_train.groupby(['State'])['Latitude'].transform('median'))
X_train['Latitude'].isnull().sum()
# Out:
# 0

# %%
X_train['Longitude']=X_train['Longitude'].fillna(X_train.groupby(['State','District','Block'])['Longitude'].transform('median'))
X_train['Longitude'].isnull().sum()
# Out:
# 163

# %%
X_train['Longitude']=X_train['Longitude'].fillna(X_train.groupby(['State','District'])['Longitude'].transform('median'))
X_train['Longitude'].isnull().sum()
# Out:
# 77

# %%
X_train['Longitude']=X_train['Longitude'].fillna(X_train.groupby(['State'])['Longitude'].transform('median'))
X_train['Longitude'].isnull().sum()
# Out:
# 0

# %% [markdown]
# X_train is completed , similarly do with other set X_test .

# %%
X_test['Latitude']=X_test['Latitude'].fillna(X_train.groupby(['State','District','Block'])['Latitude'].transform('median'))
X_test['Latitude'].isnull().sum()
# Out:
# 71

# %%
X_test['Latitude']=X_test['Latitude'].fillna(X_test.groupby(['State','District'])['Latitude'].transform('median'))
X_test['Latitude'].isnull().sum()
# Out:
# 9

# %%
X_test['Latitude']=X_test['Latitude'].fillna(X_test.groupby(['State'])['Latitude'].transform('median'))
X_test['Latitude'].isnull().sum()
# Out:
# 0

# %%
X_test['Longitude']=X_test['Longitude'].fillna(X_test.groupby(['State','District','Block'])['Longitude'].transform('median'))
X_test['Longitude'].isnull().sum()
# Out:
# 47

# %%
X_test['Longitude']=X_test['Longitude'].fillna(X_test.groupby(['State','District'])['Longitude'].transform('median'))
X_test['Longitude'].isnull().sum()
# Out:
# 9

# %%
X_test['Longitude']=X_test['Longitude'].fillna(X_test.groupby(['State'])['Longitude'].transform('median'))
X_test['Longitude'].isnull().sum()
# Out:
# 0

# %% [markdown]
# __Let's delete the un-needed column of categories__

# %%
X_train.drop(['State','District','Block','Village'],inplace=True,axis=1)
X_test.drop(['State','District','Block','Village'],inplace=True,axis=1)

# %%
X_test.isnull().sum()
# Out:
# Latitude     0
# Longitude    0
# Year         0
# pH           0
# CO3          0
# HCO3         0
# SO4          0
# NO3          0
# K            0
# F            0
# dtype: int64

# %% [markdown]
# # Step 6 :- Apply Normalization and conversion in tensor values.

# %%
from sklearn.preprocessing import MinMaxScaler
import torch

# %%
scaler=MinMaxScaler()

# %%
X_train_values=scaler.fit_transform(X_train)
type(X_train_values)
# Out:
# numpy.ndarray

# %%
X_test_values=scaler.transform(X_test)

# %%
# feature data already converted in numpy array , we need to convert Label data
Y1_test=Y1_test.values
Y1_train=Y1_train.values
Y2_train=Y2_train.values
Y2_test=Y2_test.values

# %%
X_train_tensor=torch.tensor(X_train_values,dtype=torch.float32)
X_test_tensor=torch.tensor(X_test_values,dtype=torch.float32)
Y1_train_tensor=torch.tensor(Y1_train,dtype=torch.float32)
Y1_test_tensor=torch.tensor(Y1_test,dtype=torch.float32)
Y2_train_tensor=torch.tensor(Y2_train,dtype=torch.float32)
Y2_test_tensor=torch.tensor(Y2_test,dtype=torch.float32)

# %% [markdown]
# # Step 7 :- Building the Neural Network , Dataset and Tensor data loader

# %%
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset,DataLoader,Dataset

# %% [markdown]
# __1)Let's create a custom dataset function__

# %%
class preparingDataset(Dataset):
    def __init__(self,features,class_lables,reg_labels):
        self.features=features
        self.class_lables=class_lables
        self.reg_labels=reg_labels

    def __len__(self):
        return len(self.features)

    def __getitem__(self,index):
        return self.features[index],(self.class_lables[index],self.reg_labels[index])

# %% [markdown]
# __2)Let's create out model class__

# %%
#For MultiClassification model 
class MultiModel(nn.Module):
    def __init__(self,input_num,output_num):
        super(MultiModel,self).__init__()
        self.l1=nn.Linear(input_num,256)
        self.n1=nn.BatchNorm1d(256)
        self.d1=nn.Dropout(0.5)

        self.l2=nn.Linear(256,128)
        self.n2=nn.BatchNorm1d(128)
        self.d2=nn.Dropout(0.5)

        self.l3=nn.Linear(128,64)
        self.n3=nn.BatchNorm1d(64)
        self.d3=nn.Dropout(0.5)

        self.l4=nn.Linear(64,output_num) # For multi classification, output_num= 5 multi classes.for regression outpout_num=1

    def forward(self,x):
        x=F.leaky_relu(self.n1(self.l1(x)),negative_slope=0.01)
        x=self.d1(x)
        x=F.leaky_relu(self.n2(self.l2(x)),negative_slope=0.01)
        x=self.d2(x)
        x=F.leaky_relu(self.n3(self.l3(x)),negative_slope=0.01)
        x=self.d3(x)
       # x=F.softmax(self.l4(x)) we can't use softmax function because our loss function will apply softmax function internally
        x=self.l4(x)
        return x

# %% [markdown]
# __3)Let's create training and evalution fun__

# %%
from sklearn.metrics import r2_score,accuracy_score,f1_score,mean_absolute_error

# %%
from sklearn.metrics import accuracy_score, f1_score, mean_absolute_error, r2_score
import matplotlib.pyplot as plt

def train_and_evaluate(
    model_clas,
    model_reg,
    train_loader,
    val_loader,
    optimizer_clas,
    optimizer_reg,
    num_epochs,
    patience=5,  # Early stopping patience
    class_criterion=nn.CrossEntropyLoss(),
    reg_criterion=nn.MSELoss()
):
    best_val_loss_clas = float('inf')
    best_val_loss_reg = float('inf')
    patience_counter_clas = 0
    patience_counter_reg = 0
    best_model_clas = None
    best_model_reg = None

    train_loss_clas_list = []
    train_loss_reg_list = []
    val_loss_clas_list = []
    val_loss_reg_list = []

    for epoch in range(num_epochs):
        # Training phase
        model_clas.train()
        model_reg.train()
        
        train_class_loss = 0.0
        train_reg_loss = 0.0
        num_train_batches = 0

        for inputs, (class_labels, reg_labels) in train_loader:
            # Classification Model
            optimizer_clas.zero_grad()
            class_pred = model_clas(inputs)
            class_labels = class_labels.long()  # Convert to torch.LongTensor , cross entropy need labels in long type tensor
            loss_class = class_criterion(class_pred, class_labels)
            loss_class.backward()
            optimizer_clas.step()
            train_class_loss += loss_class.item()

            # Regression Model
            optimizer_reg.zero_grad()
            reg_pred = model_reg(inputs)
            loss_reg = reg_criterion(reg_pred.squeeze(), reg_labels)
            loss_reg.backward()
            optimizer_reg.step()
            train_reg_loss += loss_reg.item()

            num_train_batches += 1

        avg_train_loss_clas = train_class_loss / num_train_batches
        avg_train_loss_reg = train_reg_loss / num_train_batches
        train_loss_clas_list.append(avg_train_loss_clas)
        train_loss_reg_list.append(avg_train_loss_reg)

        # Validation phase
        model_clas.eval()
        model_reg.eval()

        val_class_loss = 0.0
        val_reg_loss = 0.0
        num_val_batches = 0

        class_preds = []
        class_targets = []
        reg_preds = []
        reg_targets = []

        with torch.no_grad():
            for inputs, (class_labels, reg_labels) in val_loader:
                # Classification Model
                class_pred = model_clas(inputs)
                class_labels = class_labels.long()  # Convert to torch.LongTensor
                loss_class = class_criterion(class_pred, class_labels)
                val_class_loss += loss_class.item()
                class_preds.extend(torch.argmax(class_pred, dim=1).cpu().numpy())
                class_targets.extend(class_labels.cpu().numpy())

                # Regression Model
                reg_pred = model_reg(inputs)
                loss_reg = reg_criterion(reg_pred.squeeze(), reg_labels)
                val_reg_loss += loss_reg.item()
                reg_preds.extend(reg_pred.squeeze().cpu().numpy())
                reg_targets.extend(reg_labels.cpu().numpy())

                num_val_batches += 1

        avg_val_loss_clas = val_class_loss / num_val_batches
        avg_val_loss_reg = val_reg_loss / num_val_batches
        val_loss_clas_list.append(avg_val_loss_clas)
        val_loss_reg_list.append(avg_val_loss_reg)

        # Metrics
        val_accuracy = accuracy_score(class_targets, class_preds)
        val_f1 = f1_score(class_targets, class_preds, average='weighted')
        val_mae = mean_absolute_error(reg_targets, reg_preds)
        val_r2 = r2_score(reg_targets, reg_preds)

        print(
            f"Epoch {epoch+1}: "
            f"Train Loss (Clas): {avg_train_loss_clas:.4f}, Train Loss (Reg): {avg_train_loss_reg:.4f}, "
            f"Val Loss (Clas): {avg_val_loss_clas:.4f}, Val Loss (Reg): {avg_val_loss_reg:.4f}, "
            f"Val Accuracy: {val_accuracy:.4f}, Val F1: {val_f1:.4f}, "
            f"Val MAE: {val_mae:.4f}, Val R²: {val_r2:.4f}"
        )

        # Early Stopping for Classification Model
        if avg_val_loss_clas < best_val_loss_clas:
            best_val_loss_clas = avg_val_loss_clas
            patience_counter_clas = 0
            best_model_clas = model_clas.state_dict()
        else:
            patience_counter_clas += 1
            if patience_counter_clas >= patience:
                print("Early stopping triggered for classification model!")
                model_clas.load_state_dict(best_model_clas)

        # Early Stopping for Regression Model
        if avg_val_loss_reg < best_val_loss_reg:
            best_val_loss_reg = avg_val_loss_reg
            patience_counter_reg = 0
            best_model_reg = model_reg.state_dict()
        else:
            patience_counter_reg += 1
            if patience_counter_reg >= patience:
                print("Early stopping triggered for regression model!")
                model_reg.load_state_dict(best_model_reg)

    # Plot Train and Validation Loss for Classification
    plt.figure(figsize=(10, 6))
    plt.plot(train_loss_clas_list, label='Train Loss (Classification)')
    plt.plot(val_loss_clas_list, label='Validation Loss (Classification)')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Train vs Validation Loss (Classification)')
    plt.legend()
    plt.show()

    # Plot Train and Validation Loss for Regression
    plt.figure(figsize=(10, 6))
    plt.plot(train_loss_reg_list, label='Train Loss (Regression)')
    plt.plot(val_loss_reg_list, label='Validation Loss (Regression)')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Train vs Validation Loss (Regression)')
    plt.legend()
    plt.show()

    return model_clas, model_reg

# %% [markdown]
# # Step 8:- finally train and evaluate our model

# %%
model_clas = MultiModel(X_train.shape[1],5)  # Define your classification model
model_reg = MultiModel(X_train.shape[1],1)  # Define your regression model
optimizer_clas = torch.optim.Adam(model_clas.parameters(), lr=0.001)
optimizer_reg = torch.optim.Adam(model_reg.parameters(), lr=0.001)
train_loader=DataLoader(preparingDataset(X_train_tensor,Y2_train_tensor,Y1_train_tensor),batch_size=128,shuffle=True)
val_loader=DataLoader(preparingDataset(X_test_tensor,Y2_test_tensor,Y1_test_tensor),batch_size=128,shuffle=True)
train_and_evaluate(
    model_clas=model_clas,
    model_reg=model_reg,
    train_loader=train_loader,
    val_loader=val_loader,
    optimiz
# Early stopping triggered for classification model!
# Early stopping triggered for regression model!
# Epoch 27: Train Loss (Clas): 0.7432, Train Loss (Reg): 37608.6823, Val Loss (Clas): 0.6948, Val Loss (Reg): 40175.7433, Val Accuracy: 0.7015, Val F1: 0.7021, Val MAE: 80.2887, Val R²: 0.6189
# Early stopping triggered for classification model!
# Early stopping triggered for regression model!
# Epoch 28: Train Loss (Clas): 0.7506, Train Loss (Reg): 38101.8835, Val Loss (Clas): 0.6958, Val Loss (Reg): 43300.1418, Val Accuracy: 0.7081, Val F1: 0.7076, Val MAE: 79.5971, Val R²: 0.5880
# Early stopping triggered for classification model!
# Early stopping triggered for regression model!
# Epoch 29: Train Loss (Clas): 0.7478, Train Loss (Reg): 36156.4622, Val Loss (Clas): 0.6928, Val Loss (Reg): 43371.1540, Val Accuracy: 0.7065, Val F1: 0.7076, Val MAE: 76.4545, Val R²: 0.5981
# Early stopping triggered for classification model!
# Early stopping triggered for regression model!
# Epoch 30: Train Loss (Clas): 0.7353, Train Loss (Reg): 35949.5649, Val Loss (Clas): 0.6872, Val Loss (Reg): 40653.7136, Val Accuracy: 0.7128, Val F1: 0.7138, Val MAE: 78.9484, Val R²: 0.6123
# Early stopping triggered for classification model!
# Early stopping triggered for regression model!
# Epoch 31: Train Loss (Clas): 0.7410, Train Loss (Reg): 35156.1385, Val Loss (Clas): 0.6883, Val Loss (Reg): 43203.0031, Val Accuracy: 0.7136, Val F1: 0.7136, Val MAE: 76.9226, Val R²: 0.6143
# Early stopping triggered for classification model!
# Early stopping triggered for regression model!
# Epoch 32: Train Loss (Clas): 0.7422, Train Loss (Reg): 36862.7618, Val Loss (Clas): 0.7076, Val Loss (Reg): 42537.7016, Val Accuracy: 0.6997, Val F1: 0.6988, Val MAE: 79.6220, Val R²: 0.6196
# Early stopping triggered for classification model!
# Early stopping triggered for regression model!
# Epoch 33: Train Loss (Clas): 0.7379, Train Loss (Reg): 34560.8325, Val Loss (Clas): 0.6891, Val Loss (Reg): 38778.2327, Val Accuracy: 0.7141, Val F1: 0.7169, Val MAE: 76.0339, Val R²: 0.6293
# Early stopping triggered for classification model!
# Epoch 34: Train Loss (Clas): 0.7404, Train Loss (Reg): 37702.6980, Val Loss (Clas): 0.6856, Val Loss (Reg): 41396.3668, Val Accuracy: 0.7152, Val F1: 0.7166, Val MAE: 74.8989, Val R²: 0.6197
# Epoch 35: Train Loss (Clas): 0.7385, Train Loss (Reg): 36042.7851, Val Loss (Clas): 0.6977, Val Loss (Reg): 41902.1409, Val Accuracy: 0.7086, Val F1: 0.7090, Val MAE: 78.1629, Val R²: 0.5991
# Epoch 36: Train Loss (Clas): 0.7346, Train Loss (Reg): 37385.5275, Val Loss (Clas): 0.6845, Val Loss (Reg): 41344.8309, Val Accuracy: 0.7152, Val F1: 0.7150, Val MAE: 77.6306, Val R²: 0.6050
# Epoch 49: Train Loss (Clas): 0.7333, Train Loss (Reg): 35742.0240, Val Loss (Clas): 0.6807, Val Loss (Reg): 39186.3853, Val Accuracy: 0.7178, Val F1: 0.7150, Val MAE: 76.4132, Val R²: 0.6253
# Early stopping triggered for classification model!
# Early stopping triggered for regression model!
# Epoch 50: Train Loss (Clas): 0.7235, Train Loss (Reg): 35273.4292, Val Loss (Clas): 0.6788, Val Loss (Reg): 39818.4501, Val Accuracy: 0.7154, Val F1: 0.7154, Val MAE: 74.9490, Val R²: 0.6192
# Early stopping triggered for classification model!
# Early stopping triggered for regression model!
# (MultiModel(
#    (l1): Linear(in_features=10, out_features=256, bias=True)
#    (n1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (d1): Dropout(p=0.5, inplace=False)
#    (l2): Linear(in_features=256, out_features=128, bias=True)
#    (n2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (d2): Dropout(p=0.5, inplace=False)
#    (l3): Linear(in_features=128, out_features=64, bias=True)
#    (n3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (d3): Dropout(p=0.5, inplace=False)
#    (l4): Linear(in_features=64, out_features=5, bias=True)
#  ),
#  MultiModel(
#    (l1): Linear(in_features=10, out_features=256, bias=True)
#    (n1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (d1): Dropout(p=0.5, inplace=False)
#    (l2): Linear(in_features=256, out_features=128, bias=True)
#    (n2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (d2): Dropout(p=0.5, inplace=False)
#    (l3): Linear(in_features=128, out_features=64, bias=True)
#    (n3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (d3): Dropout(p=0.5, inplace=False)
#    (l4): Linear(in_features=64, out_features=1, bias=True)
#  ))

# %% [markdown]
# # Step 9 :- final testing and result of model

# %%
Y1_pred=model_reg(X_test_tensor) #output also in tensor
Y2_pred=model_clas(X_test_tensor) #it will give us probability so we need to get max prob. class by using argmax(axis=1) function
accuracy=accuracy_score(Y2_test,Y2_pred.detach().numpy().argmax(axis=1)) #need to convert in numpy array for using sklearn.metrics , 
f1Score=f1_score(Y2_test,Y2_pred.detach().numpy().argmax(axis=1),average='weighted') #avg=weigh for multiclass problem 
r2Score=r2_score(Y1_test,Y1_pred.detach().numpy())
mean_absolute_errors=mean_absolute_error(Y1_test,Y1_pred.detach().numpy())
print("Final Results:")
print(f"Regression - MAE: {mean_absolute_errors}, R²: {r2Score}")
print(f"Classification - Accuracy: {accuracy}, F1-Score: {f1Score}")
# Out:
# Final Results:
# Regression - MAE: 74.94899461074455, R²: 0.6192014305586495
# Classification - Accuracy: 0.7154492905937992, F1-Score: 0.7153768470512203

# %% [markdown]
# # Step :-10 Apply Hyper tunning for getting best parameters for our model.

# %%
import optuna
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from sklearn.metrics import accuracy_score, mean_absolute_error

# Objective function for Optuna
def objective(trial):
    # Hyperparameters to tune
    lr_clas = trial.suggest_float('lr_clas', 1e-5, 1e-2, log=True)
    lr_reg = trial.suggest_float('lr_reg', 1e-5, 1e-2, log=True)
    dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.5)
    hidden_size_1 = trial.suggest_int('hidden_size_1', 64, 512, step=64)
    hidden_size_2 = trial.suggest_int('hidden_size_2', 64, 256, step=64)

    # Define model
    class MultiModelOptuna(nn.Module):
        def __init__(self, input_num, output_num, dropout_rate):
            super(MultiModelOptuna, self).__init__()
            self.l1 = nn.Linear(input_num, hidden_size_1)
            self.n1 = nn.BatchNorm1d(hidden_size_1)
            self.d1 = nn.Dropout(dropout_rate)

            self.l2 = nn.Linear(hidden_size_1, hidden_size_2)
            self.n2 = nn.BatchNorm1d(hidden_size_2)
            self.d2 = nn.Dropout(dropout_rate)

            self.l3 = nn.Linear(hidden_size_2, output_num)

        def forward(self, x):
            x = F.leaky_relu(self.n1(self.l1(x)))
            x = self.d1(x)
            x = F.leaky_relu(self.n2(self.l2(x)))
            x = self.d2(x)
            x = self.l3(x)
            return x

    model_clas = MultiModelOptuna(X_train_tensor.shape[1], 5, dropout_rate)
    model_reg = MultiModelOptuna(X_train_tensor.shape[1], 1, dropout_rate)

    optimizer_clas = torch.optim.Adam(model_clas.parameters(), lr=lr_clas)
    optimizer_reg = torch.optim.Adam(model_reg.parameters(), lr=lr_reg)

    class_criterion = nn.CrossEntropyLoss()
    reg_criterion = nn.MSELoss()

    # DataLoader
    train_loader = DataLoader(preparingDataset(X_train_tensor, Y2_train_tensor, Y1_train_tensor), batch_size=128, shuffle=True)
    val_loader = DataLoader(preparingDataset(X_test_tensor, Y2_test_tensor, Y1_test_tensor), batch_size=128, shuffle=False)

    # Training loop (single epoch for simplicity in tuning)
    model_clas.train()
    model_reg.train()
    for inputs, (class_labels, reg_labels) in train_loader:
        # Classification training
        optimizer_clas.zero_grad()
        class_pred = model_clas(inputs)
        loss_clas = class_criterion(class_pred, class_labels.long())
        loss_clas.backward()
        optimizer_clas.step()

        # Regression training
        optimizer_reg.zero_grad()
        reg_pred = model_reg(inputs)
        loss_reg = reg_criterion(reg_pred.squeeze(), reg_labels)
        loss_reg.backward()
        optimizer_reg.step()

    # Validation
    model_clas.eval()
    model_reg.eval()

    class_preds = []
    class_targets = []
    reg_preds = []
    reg_targets = []

    with torch.no_grad():
        for inputs, (class_labels, reg_labels) in val_loader:
            class_pred = model_clas(inputs)
            class_preds.extend(torch.argmax(class_pred, dim=1).cpu().numpy())
            class_targets.extend(class_labels.cpu().numpy())

            reg_pred = model_reg(inputs)
            reg_preds.extend(reg_pred.squeeze().cpu().numpy())
            reg_targets.extend(reg_labels.cpu().numpy())

    # Metrics
    val_accuracy = accuracy_score(class_targets, class_preds)
    val_mae = mean_absolute_error(reg_targets, reg_preds)

    # Combined score (you can adjust the weighting)
    score = val_accuracy - val_mae
    return score

# Run Optuna study
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

# Best trial
print("Best trial:")
print(f"Value: {study.best_trial.value}")
print("Params:")
for key, value in study.best_trial.params.items():
    print(f"  {key}: {value}")
# Out:
# [I 2025-01-09 19:35:32,294] A new study created in memory with name: no-name-6a543286-8c98-40b6-81f6-1b74493e162c
# C:\Users\govinda.tak\AppData\Local\Temp\ipykernel_9716\2853117497.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.5)
# [I 2025-01-09 19:35:33,518] Trial 0 finished with value: -307.8844618764728 and parameters: {'lr_clas': 0.000409470767728905, 'lr_reg': 8.647511812917592e-05, 'dropout_rate': 0.22974688559773326, 'hidden_size_1': 512, 'hidden_size_2': 192}. Best is trial 0 with value: -307.8844618764728.
# C:\Users\govinda.tak\AppData\Local\Temp\ipykernel_9716\2853117497.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.5)
# [I 2025-01-09 19:35:34,469] Trial 1 finished with value: -237.49008011128862 and parameters: {'lr_clas': 0.00165658461671944, 'lr_reg': 0.00342073056780413, 'dropout_rate': 0.43973765831910405, 'hidden_size_1': 192, 'hidden_size_2': 192}. Best is trial 1 with value: -237.49008011128862.
# C:\Users\govinda.tak\AppData\Local\Temp\ipykernel_9716\2853117497.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.5)
# [I 2025-01-09 19:35
 'hidden_size_2': 128}. Best is trial 11 with value: -90.94643657481865.
# C:\Users\govinda.tak\AppData\Local\Temp\ipykernel_9716\2853117497.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.5)
# [I 2025-01-09 19:36:00,840] Trial 29 finished with value: -308.24706359318037 and parameters: {'lr_clas': 0.0003934694819805688, 'lr_reg': 0.00013113449889121573, 'dropout_rate': 0.24610371347217253, 'hidden_size_1': 512, 'hidden_size_2': 192}. Best is trial 11 with value: -90.94643657481865.
# C:\Users\govinda.tak\AppData\Local\Temp\ipykernel_9716\2853117497.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.5)
# [I 2025-01-09 19:36:01,555] Trial 30 finished with value: -307.0586829132866 and parameters: {'lr_clas': 1.2261877192062216e-05, 'lr_reg': 0.0005458983609742563, 'dropout_rate': 0.4143421905906615, 'hidden_size_1': 384, 'hidden_size_2': 64}. Best is trial 11 with value: -90.94643657481865.
# C:\Users\govinda.tak\AppData\Local\Temp\ipykernel_9716\2853117497.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.5)
# [I 2025-01-09 19:36:02,385] Trial 31 finished with value: -158.6810446662522 and parameters: {'lr_clas': 6.275102023425355e-05, 'lr_reg': 0.006103610082286209, 'dropout_rate': 0.2937395916628572, 'hidden_size_1': 448, 'hidden_size_2': 128}. Best is trial 11 with value: -90.94643657481865.
# C:\Users\govinda.tak\AppData\Local\Temp\ipykernel_9716\2853117497.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.5)
# [I 2025-01-09 19:36:03,363] Trial 32 finished with value: -253.73732120515922 and parameters: {'lr_clas': 8.28062185197795e-05, 'lr_reg': 0.0036677693510313893, 'dropout_rate': 0.208948547602212, 'hidden_size_1': 448, 'hidden_size_2': 128}. Best is trial 11 with value: -90.94643657481865.
# C:\Users\govinda.tak\AppData\Local\Temp\ipykernel_9716\2853117497.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.5)
# [I 2025-01-09 19:36:04,369] Trial 33 finished with value: -158.3321835091411 and parameters: {'lr_clas': 0.00024570206920621133, 'lr_reg': 0.006369484635742117, 'dropout_rate': 0.2783891674672448, 'hidden_size_1': 448, 'hidden_size_2': 128}. Best is trial 11 with value: -90.94643657481865.
# C:\Users\govinda.tak\AppData\Local\Temp\ipykernel_9716\2853117497.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.5)
# [I 2025-01-09 19:36:05,430] Trial 34 finished with value: -281.43794972935416 and parameters: {'lr_clas': 3.761144946274159e-05, 'lr_reg': 0.0023280365601635405, 'dropout_rate': 0.31840480469953636, 'hidden_size_1': 384, 'hidden_size_2': 192}. Best is trial 11 with value: -90.94643657481865.
# C:\Users\govinda.tak\AppData\Local\Temp\ipykernel_9716\2853117497.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.5)
# [I 2025-01-09 19:36:06,401] Trial 35 finished with value: -242.84899967291827 and parameters: {'lr_clas': 0.00011533934020064425, 'lr_reg': 0.004211879442609212, 'dropout_rate': 0.3429981336291826, 'hidden_size_1': 512, 'hidden_size_2': 128}. Best is trial 11 with value: -90.94643657481865.
# C:\Users\govinda.tak\AppData\Local\Temp\ipykernel_9716\2853117497.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.5)
# [I 2025-01-09 19:36:07,215] Trial 36 finished with value: -100.13787598442042 and parameters: {'lr_clas': 0.00214559696035326, 'lr_reg': 0.006316323935946779, 'dropout_rate': 0.28887322709426005, 'hidden_size_1': 320, 'hidden_size_2': 192}. Best is trial 11 with value: -90.94643657481865.
# C:\Users\govinda.tak\AppData\Local\Temp\ipykernel_9716\2853117497.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.5)
# [I 2025-01-09 19:36:08,076] Trial 37 finished with value: -290.5185547676828 and parameters: {'lr_clas': 0.0023639785326899543, 'lr_reg': 0.0014550404959010397, 'dropout_rate': 0.3845240606578848, 'hidden_size_1': 320, 'hidden_size_2': 192}. Best is trial 11 with value: -90.94643657481865.
# C:\Users\govinda.tak\AppData\Local\Temp\ipykernel_9716\2853117497.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.5)
# [I 2025-01-09 19:36:08,884] Trial 38 finished with value: -115.05095383147471 and parameters: {'lr_clas': 0.005301415449156201, 'lr_reg': 0.007201778892141226, 'dropout_rate': 0.4518869323715404, 'hidden_size_1': 128, 'hidden_size_2': 256}. Best is trial 11 with value: -90.94643657481865.
# C:\Users\govinda.tak\AppData\Local\Temp\ipykernel_9716\2853117497.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.5)
# [I 2025-01-09 19:36:09,682] Trial 39 finished with value: -248.8890089234489 and parameters: {'lr_clas': 0.007065105693793126, 'lr_reg': 0.0029902751791750044, 'dropout_rate': 0.45326260519040007, 'hidden_size_1': 128, 'hidden_size_2': 256}. Best is trial 11 with value: -90.94643657481865.
# C:\Users\govinda.tak\AppData\Local\Temp\ipykernel_9716\2853117497.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.5)
# [I 2025-01-09 19:36:10,502] Trial 40 finished with value: -308.405550372895 and parameters: {'lr_clas': 0.0050316106945352485, 'lr_reg': 6.299503419860482e-05, 'dropout_rate': 0.49629753357159306, 'hidden_size_1': 128, 'hidden_size_2': 256}. Best is trial 11 with value: -90.94643657481865.
# C:\Users\govinda.tak\AppData\Local\Temp\ipykernel_9716\2853117497.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.5)
# [I 2025-01-09 19:36:11,378] Trial 41 finished with value: -108.7962459778698 and parameters: {'lr_clas': 0.0018173638956757152, 'lr_reg': 0.006901888321886252, 'dropout_rate': 0.2661225216891348, 'hidden_size_1': 256, 'hidden_size_2': 256}. Best is trial 11 with value: -90.94643657481865.
# C:\Users\govinda.tak\AppData\Local\Temp\ipykernel_9716\2853117497.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.5)
# [I 2025-01-09 19:36:12,178] Trial 42 finished with value: -113.48558782115461 and parameters: {'lr_clas': 0.00187767308342847, 'lr_reg': 0.0068136271304425865, 'dropout_rate': 0.2574590609253242, 'hidden_size_1': 128, 'hidden_size_2': 256}. Best is trial 11 with value: -90.94643657481865.
# C:\Users\govinda.tak\AppData\Local\Temp\ipykernel_9716\2853117497.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.5)
# [I 2025-01-09 19:36:13,005] Trial 43 finished with value: -195.2250886276654 and parameters: {'lr_clas': 0.0017837693462203796, 'lr_reg': 0.0041976823681974485, 'dropout_rate': 0.2652896621263479, 'hidden_size_1': 192, 'hidden_size_2': 256}. Best is trial 11 with value: -90.94643657481865.
# C:\Users\govinda.tak\AppData\Local\Temp\ipykernel_9716\2853117497.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.5)
# [I 2025-01-09 19:36:13,849] Trial 44 finished with value: -88.25297244097519 and parameters: {'lr_clas': 0.00299774720251868, 'lr_reg': 0.006773079973624131, 'dropout_rate': 0.21452220226990804, 'hidden_size_1': 256, 'hidden_size_2': 256}. Best is trial 44 with value: -88.25297244097519.
# C:\Users\govinda.tak\AppData\Local\Temp\ipykernel_9716\2853117497.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.5)
# [I 2025-01-09 19:36:14,680] Trial 45 finished with value: -174.083777278834 and parameters: {'lr_clas': 0.003573232574329699, 'lr_reg': 0.005343681568901585, 'dropout_rate': 0.17553806779522615, 'hidden_size_1': 256, 'hidden_size_2': 192}. Best is trial 44 with value: -88.25297244097519.
# C:\Users\govinda.tak\AppData\Local\Temp\ipykernel_9716\2853117497.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.5)
# [I 2025-01-09 19:36:15,558] Trial 46 finished with value: -223.89932964603585 and parameters: {'lr_clas': 0.0012361273016857565, 'lr_reg': 0.002887665818914128, 'dropout_rate': 0.20927190093162273, 'hidden_size_1': 256, 'hidden_size_2': 256}. Best is trial 44 with value: -88.25297244097519.
# C:\Users\govinda.tak\AppData\Local\Temp\ipykernel_9716\2853117497.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.5)
# [I 2025-01-09 19:36:16,443] Trial 47 finished with value: -87.44142171726438 and parameters: {'lr_clas': 0.0025036247838682484, 'lr_reg': 0.009984342685264581, 'dropout_rate': 0.19433882802261604, 'hidden_size_1': 256, 'hidden_size_2': 256}. Best is trial 47 with value: -87.44142171726438.
# C:\Users\govinda.tak\AppData\Local\Temp\ipykernel_9716\2853117497.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.5)
# [I 2025-01-09 19:36:17,255] Trial 48 finished with value: -99.49891382358729 and parameters: {'lr_clas': 0.0008432143286850039, 'lr_reg': 0.00961238713431402, 'dropout_rate': 0.1358317212993186, 'hidden_size_1': 320, 'hidden_size_2': 192}. Best is trial 47 with value: -87.44142171726438.
# C:\Users\govinda.tak\AppData\Local\Temp\ipykernel_9716\2853117497.py:13: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.1, 0.5)
# [I 2025-01-09 19:36:18,007] Trial 49 finished with value: -106.29471754915014 and parameters: {'lr_clas': 0.0006681693125234466, 'lr_reg': 0.008978373134548173, 'dropout_rate': 0.12147661418968578, 'hidden_size_1': 192, 'hidden_size_2': 192}. Best is trial 47 with value: -87.44142171726438.
# Best trial:
# Value: -87.44142171726438
# Params:
#   lr_clas: 0.0025036247838682484
#   lr_reg: 0.009984342685264581
#   dropout_rate: 0.19433882802261604
#   hidden_size_1: 256
#   hidden_size_2: 256

# %%
# Define models with optimal hyperparameters
model_clas = MultiModel(X_train.shape[1], 5)
model_reg = MultiModel(X_train.shape[1], 1)

# Use the best dropout rate
model_clas.d1.p = 0.194
model_clas.d2.p = 0.194
model_clas.d3.p = 0.194

model_reg.d1.p = 0.194
model_reg.d2.p = 0.194
model_reg.d3.p = 0.194

# Optimizers with best learning rates
optimizer_clas = torch.optim.Adam(model_clas.parameters(), lr=0.0025)
optimizer_reg = torch.optim.Adam(model_reg.parameters(), lr=0.00998)

train_loader=DataLoader(preparingDataset(X_train_tensor,Y2_train_tensor,Y1_train_tensor),batch_size=128,shuffle=True)
val_loader=DataLoader(preparingDataset(X_test_tensor,Y2_test_tensor,Y1_test_tensor),batch_size=128,shuffle=True)
train_and_evaluate(
    model_clas=model_clas,
    model_reg=model_reg,
    train_loader=train_loader,
    val_loader=val_loader,
    optimiz
# Epoch 14: Train Loss (Clas): 0.7013, Train Loss (Reg): 32162.2407, Val Loss (Clas): 0.6933, Val Loss (Reg): 38943.6724, Val Accuracy: 0.6986, Val F1: 0.7010, Val MAE: 76.3225, Val R²: 0.6286
# Early stopping triggered for classification model!
# Epoch 15: Train Loss (Clas): 0.6913, Train Loss (Reg): 33475.5474, Val Loss (Clas): 0.6894, Val Loss (Reg): 39629.8691, Val Accuracy: 0.7068, Val F1: 0.7114, Val MAE: 76.8652, Val R²: 0.6215
# Early stopping triggered for classification model!
# Epoch 16: Train Loss (Clas): 0.6994, Train Loss (Reg): 32514.9889, Val Loss (Clas): 0.6791, Val Loss (Reg): 39866.1723, Val Accuracy: 0.7165, Val F1: 0.7172, Val MAE: 76.6629, Val R²: 0.6189
# Early stopping triggered for classification model!
# Epoch 17: Train Loss (Clas): 0.6990, Train Loss (Reg): 32794.7366, Val Loss (Clas): 0.6756, Val Loss (Reg): 39362.3379, Val Accuracy: 0.7170, Val F1: 0.7103, Val MAE: 79.2686, Val R²: 0.6240
# Early stopping triggered for classification model!
# Epoch 18: Train Loss (Clas): 0.6964, Train Loss (Reg): 30965.9005, Val Loss (Clas): 0.6716, Val Loss (Reg): 38067.0410, Val Accuracy: 0.7189, Val F1: 0.7205, Val MAE: 77.5721, Val R²: 0.6366
# Early stopping triggered for classification model!
# Epoch 19: Train Loss (Clas): 0.6941, Train Loss (Reg): 32250.2822, Val Loss (Clas): 0.6807, Val Loss (Reg): 38784.3174, Val Accuracy: 0.7133, Val F1: 0.7100, Val MAE: 79.8368, Val R²: 0.6313
# Early stopping triggered for classification model!
# Epoch 20: Train Loss (Clas): 0.6941, Train Loss (Reg): 31603.1805, Val Loss (Clas): 0.6803, Val Loss (Reg): 39298.4591, Val Accuracy: 0.7039, Val F1: 0.7040, Val MAE: 91.9333, Val R²: 0.6255
# Early stopping triggered for classification model!
# Epoch 21: Train Loss (Clas): 0.6947, Train Loss (Reg): 32224.7145, Val Loss (Clas): 0.6895, Val Loss (Reg): 38293.2883, Val Accuracy: 0.7036, Val F1: 0.7028, Val MAE: 74.6585, Val R²: 0.6344
# Early stopping triggered for classification model!
# Epoch 22: Train Loss (Clas): 0.6927, Train Loss (Reg): 31116.7917, Val Loss (Clas): 0.6829, Val Loss (Reg): 38317.5498, Val Accuracy: 0.7133, Val F1: 0.7145, Val MAE: 74.4403, Val R²: 0.6335
# Early stopping triggered for classification model!
# Epoch 23: Train Loss (Clas): 0.6916, Train Loss (Reg): 31865.3630, Val Loss (Clas): 0.6848, Val Loss (Reg): 38811.0792, Val Accuracy: 0.7105, Val F1: 0.7141, Val MAE: 74.8324, Val R²: 0.6424
# Early stopping triggered for classification model!
# Early stopping triggered for regression model!
# Epoch 24: Train Loss (Clas): 0.6908, Train Loss (Reg): 30881.1909, Val Loss (Clas): 0.6831, Val Loss (Reg): 39751.1923, Val Accuracy: 0.7099, Val F1: 0.7062, Val MAE: 82.7400, Val R²: 0.6324
# Early stopping triggered for classification model!
# Early stopping triggered for regression model!
# Epoch 25: Train Loss (Clas): 0.6928, Train Loss (Reg): 30437.1875, Val Loss (Clas): 0.6673, Val Loss (Reg): 38541.0957, Val Accuracy: 0.7191, Val F1: 0.7201, Val MAE: 77.3883, Val R²: 0.6314
# Early stopping triggered for regression model!
# Epoch 26: Train Loss (Clas): 0.6900, Train Loss (Reg): 30970.1186, Val Loss (Clas): 0.6717, Val Loss (Reg): 39435.6797, Val Accuracy: 0.7197, Val F1: 0.7215, Val MAE: 75.0956, Val R²: 0.6236
# Early stopping triggered for regression model!
# Epoch 27: Train Loss (Clas): 0.6936, Train Loss (Reg): 31476.4860, Val Loss (Clas): 0.6684, Val Loss (Reg): 38334.6395, Val Accuracy: 0.7165, Val F1: 0.7181, Val MAE: 78.3061, Val R²: 0.6339
# Early stopping triggered for regression model!
# Epoch 28: Train Loss (Clas): 0.6839, Train Loss (Reg): 30889.6393, Val Loss (Clas): 0.6660, Val Loss (Reg): 39235.5798, Val Accuracy: 0.7178, Val F1: 0.7165, Val MAE: 76.2862, Val R²: 0.6302
# Early stopping triggered for regression model!
# Epoch 29: Train Loss (Clas): 0.6799, Train Loss (Reg): 31365.2811, Val Loss (Clas): 0.6704, Val Loss (Reg): 41468.3924, Val Accuracy: 0.7105, Val F1: 0.7072, Val MAE: 79.5244, Val R²: 0.6278
# Early stopping triggered for regression model!
# Epoch 30: Train Loss (Clas): 0.6760, Train Loss (Reg): 31396.4142, Val Loss (Clas): 0.7239, Val Loss (Reg): 41115.0198, Val Accuracy: 0.6850, Val F1: 0.6835, Val MAE: 78.2946, Val R²: 0.6082
# Early stopping triggered for regression model!
# Epoch 31: Train Loss (Clas): 0.6865, Train Loss (Reg): 29906.9020, Val Loss (Clas): 0.6632, Val Loss (Reg): 39043.4762, Val Accuracy: 0.7204, Val F1: 0.7192, Val MAE: 86.9560, Val R²: 0.6271
# Early stopping triggered for regression model!
# Epoch 32: Train Loss (Clas): 0.6790, Train Loss (Reg): 30411.9195, Val Loss (Clas): 0.6659, Val Loss (Reg): 39500.3378, Val Accuracy: 0.7189, Val F1: 0.7173, Val MAE: 79.7892, Val R²: 0.6238
# Early stopping triggered for regression model!
# Epoch 33: Train Loss (Clas): 0.6836, Train Loss (Reg): 30611.7379, Val Loss (Clas): 0.7033, Val Loss (Reg): 38885.1982, Val Accuracy: 0.6931, Val F1: 0.6919, Val MAE: 80.9747, Val R²: 0.6288
# Early stopping triggered for regression model!
# Epoch 34: Train Loss (Clas): 0.6788, Train Loss (Reg): 30531.2048, Val Loss (Clas): 0.7089, Val Loss (Reg): 38698.8208, Val Accuracy: 0.6894, Val F1: 0.6943, Val MAE: 78.4733, Val R²: 0.6304
# Early stopping triggered for regression model!
# Epoch 35: Train Loss (Clas): 0.6782, Train Loss (Reg): 31102.2971, Val Loss (Clas): 0.6817, Val Loss (Reg): 39752.4009, Val Accuracy: 0.7105, Val F1: 0.7074, Val MAE: 75.8764, Val R²: 0.6351
# Early stopping triggered for regression model!
# Epoch 36: Train Loss (Clas): 0.6803, Train Loss (Reg): 31050.5765, Val Loss (Clas): 0.6740, Val Loss (Reg): 39440.1510, Val Accuracy: 0.7147, Val F1: 0.7154, Val MAE: 82.3839, Val R²: 0.6229
# Early stopping triggered for classification model!
# Early stopping triggered for regression model!
# Epoch 37: Train Loss (Clas): 0.6881, Train Loss (Reg): 30243.7098, Val Loss (Clas): 0.6731, Val Loss (Reg): 37653.8624, Val Accuracy: 0.7149, Val F1: 0.7166, Val MAE: 84.8626, Val R²: 0.6417
# Early stopping triggered for classification model!
# Epoch 38: Train Loss (Clas): 0.6753, Train Loss (Reg): 29080.6014, Val Loss (Clas): 0.6779, Val Loss (Reg): 37798.4631, Val Accuracy: 0.7136, Val F1: 0.7178, Val MAE: 80.9169, Val R²: 0.6391
# Early stopping triggered for classification model!
# Epoch 39: Train Loss (Clas): 0.6797, Train Loss (Reg): 29771.1607, Val Loss (Clas): 0.6702, Val Loss (Reg): 37559.8971, Val Accuracy: 0.7139, Val F1: 0.7181, Val MAE: 78.2013, Val R²: 0.6411
# Early stopping triggered for classification model!
# Epoch 40: Train Loss (Clas): 0.6737, Train Loss (Reg): 30100.4359, Val Loss (Clas): 0.6698, Val Loss (Reg): 41778.8351, Val Accuracy: 0.7173, Val F1: 0.7157, Val MAE: 75.2190, Val R²: 0.6148
# Early stopping triggered for classification model!
# Epoch 41: Train Loss (Clas): 0.6766, Train Loss (Reg): 30342.0100, Val Loss (Clas): 0.7367, Val Loss (Reg): 38838.8534, Val Accuracy: 0.6802, Val F1: 0.6750, Val MAE: 80.1915, Val R²: 0.6285
# Early stopping triggered for classification model!
# Epoch 42: Train Loss (Clas): 0.6828, Train Loss (Reg): 30172.3851, Val Loss (Clas): 0.6759, Val Loss (Reg): 38296.5108, Val Accuracy: 0.7144, Val F1: 0.7166, Val MAE: 82.4257, Val R²: 0.6337
# Early stopping triggered for classification model!
# Epoch 43: Train Loss (Clas): 0.6717, Train Loss (Reg): 29859.1344, Val Loss (Clas): 0.6748, Val Loss (Reg): 41502.6438, Val Accuracy: 0.7139, Val F1: 0.7122, Val MAE: 79.9763, Val R²: 0.6037
# Early stopping triggered for classification model!
# Epoch 44: Train Loss (Clas): 0.6703, Train Loss (Reg): 29917.8288, Val Loss (Clas): 0.6865, Val Loss (Reg): 37775.5535, Val Accuracy: 0.7086, Val F1: 0.7062, Val MAE: 74.3812, Val R²: 0.6407
# Early stopping triggered for classification model!
# Early stopping triggered for regression model!
# Epoch 45: Train Loss (Clas): 0.6747, Train Loss (Reg): 29742.8559, Val Loss (Clas): 0.6686, Val Loss (Reg): 39935.0175, Val Accuracy: 0.7097, Val F1: 0.7059, Val MAE: 76.8745, Val R²: 0.6218
# Early stopping triggered for classification model!
# Early stopping triggered for regression model!
# Epoch 46: Train Loss (Clas): 0.6757, Train Loss (Reg): 29249.8677, Val Loss (Clas): 0.6852, Val Loss (Reg): 39878.3566, Val Accuracy: 0.7026, Val F1: 0.7062, Val MAE: 74.4043, Val R²: 0.6184
# Early stopping triggered for classification model!
# Early stopping triggered for regression model!
# Epoch 47: Train Loss (Clas): 0.6720, Train Loss (Reg): 29667.7322, Val Loss (Clas): 0.6959, Val Loss (Reg): 36282.5011, Val Accuracy: 0.7031, Val F1: 0.7066, Val MAE: 77.4675, Val R²: 0.6536
# Early stopping triggered for classification model!
# Epoch 48: Train Loss (Clas): 0.6741, Train Loss (Reg): 29385.7640, Val Loss (Clas): 0.7214, Val Loss (Reg): 37738.7351, Val Accuracy: 0.6844, Val F1: 0.6785, Val MAE: 77.4952, Val R²: 0.6391
# Early stopping triggered for classification model!
# Epoch 49: Train Loss (Clas): 0.6756, Train Loss (Reg): 28886.5409, Val Loss (Clas): 0.6710, Val Loss (Reg): 42681.7721, Val Accuracy: 0.7076, Val F1: 0.7114, Val MAE: 73.6334, Val R²: 0.6102
# Early stopping triggered for classification model!
# Epoch 50: Train Loss (Clas): 0.6758, Train Loss (Reg): 28327.4042, Val Loss (Clas): 0.6693, Val Loss (Reg): 39230.0580, Val Accuracy: 0.7170, Val F1: 0.7174, Val MAE: 73.3521, Val R²: 0.6258
# Early stopping triggered for classification model!
# (MultiModel(
#    (l1): Linear(in_features=10, out_features=256, bias=True)
#    (n1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (d1): Dropout(p=0.194, inplace=False)
#    (l2): Linear(in_features=256, out_features=128, bias=True)
#    (n2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (d2): Dropout(p=0.194, inplace=False)
#    (l3): Linear(in_features=128, out_features=64, bias=True)
#    (n3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (d3): Dropout(p=0.194, inplace=False)
#    (l4): Linear(in_features=64, out_features=5, bias=True)
#  ),
#  MultiModel(
#    (l1): Linear(in_features=10, out_features=256, bias=True)
#    (n1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (d1): Dropout(p=0.194, inplace=False)
#    (l2): Linear(in_features=256, out_features=128, bias=True)
#    (n2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (d2): Dropout(p=0.194, inplace=False)
#    (l3): Linear(in_features=128, out_features=64, bias=True)
#    (n3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (d3): Dropout(p=0.194, inplace=False)
#    (l4): Linear(in_features=64, out_features=1, bias=True)
#  ))

# %%
torch.save(model_clas.state_dict(), "best_model_classification.pth")
torch.save(model_reg.state_dict(), "best_model_regression.pth")

# %% [markdown]
# # Step 11:- Final result

# %%
Y1_pred=model_reg(X_test_tensor) #output also in tensor
Y2_pred=model_clas(X_test_tensor) #it will give us probability so we need to get max prob. class by using argmax(axis=1) function
accuracy=accuracy_score(Y2_test,Y2_pred.detach().numpy().argmax(axis=1)) #need to convert in numpy array for using sklearn.metrics , 
f1Score=f1_score(Y2_test,Y2_pred.detach().numpy().argmax(axis=1),average='weighted') #avg=weigh for multiclass problem 
r2Score=r2_score(Y1_test,Y1_pred.detach().numpy())
mean_absolute_errors=mean_absolute_error(Y1_test,Y1_pred.detach().numpy())
print("Final Results:")
print(f"Regression - MAE: {mean_absolute_errors}, R²: {r2Score}")
print(f"Classification - Accuracy: {accuracy}, F1-Score: {f1Score}")
# Out:
# Final Results:
# Regression - MAE: 73.35211896723199, R²: 0.6257879794386587
# Classification - Accuracy: 0.7170257488176563, F1-Score: 0.7173830052123007
